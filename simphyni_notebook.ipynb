# %%
print('hello')
# Out:
# hello

# %%
from simphyni import TreeSimulator
import pickle

# %%
with open('/Users/jpeyemi/Library/CloudStorage/Dropbox/Lieberman Lab/Personal lab notebooks/Ishaq/LiebermanLabLocal/condatest/3-Objects/simphyni_outs/simphyni_object.pkl', 'rb') as file:
    Sim : TreeSimulator = pickle.load(file)

# %%
Sim.get_trait_data()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 Sim.get_trait_data()
#
# File ~/Library/CloudStorage/Dropbox/Lieberman Lab/Personal lab notebooks/Ishaq/LiebermanLabLocal/SimPhyNI/simphyni/Simulation/tree_simulator.py:450, in TreeSimulator.get_trait_data(self)
#     446 """
#     447 Returns the trait data resulting from the simulation.
#     448 """
#     449 if self.trait_data.empty:
# --> 450     raise ValueError("Simulation not yet run.")
#     451 return self.trait_data
#
# ValueError: Simulation not yet run.

# %%
Sim.get_simulation_result()
# Out:
#        pair  first  second  ...  effect size  sys1        sys2
# 0    (0, 0)      0       0  ...     3.716010  Abi2        Abi2
# 1    (0, 1)      0       1  ...     0.965476  Abi2  AbiA_small
# 2    (0, 2)      0       2  ...     0.172075  Abi2        AbiD
# 3    (0, 3)      0       3  ...     0.655372  Abi2        AbiE
# 4    (0, 4)      0       4  ...     1.764036  Abi2        AbiG
# ..      ...    ...     ...  ...          ...   ...         ...
# 79  (0, 79)      0      79  ...    -0.012980  Abi2       Uzume
# 80  (0, 80)      0      80  ...     0.359670  Abi2    Wadjet_I
# 81  (0, 81)      0      81  ...    -1.166006  Abi2     dGTPase
# 82  (0, 82)      0      82  ...    -0.788881  Abi2       ietAS
# 83  (0, 83)      0      83  ...    -3.916796  Abi2        spbK
#
# [84 rows x 16 columns]

# %%
Sim.get_top_results()
# Out:
# /Users/jpeyemi/Library/CloudStorage/Dropbox/Lieberman Lab/Personal lab notebooks/Ishaq/LiebermanLabLocal/SimPhyNI/simphyni/Simulation/tree_simulator.py:617: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res['prevalence_sys1'] = res['first'].astype(str).map(prev)
# /Users/jpeyemi/Library/CloudStorage/Dropbox/Lieberman Lab/Personal lab notebooks/Ishaq/LiebermanLabLocal/SimPhyNI/simphyni/Simulation/tree_simulator.py:618: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
